# %%
# 字符串
'''
使用引号( ' ' 或 " " )来创建字符串。
Python 访问子字符串，可以使用方括号 [] 来截取字符串，字符串的截取的语法格式如下：变量[头下标:尾下标]
截取顺序和列表依顺序一致:  R  u  n  o  o  b
             从前面截取：: 1  2  3  4  5 :
             从后面截取：：-5 -4 -3 -2 -1:
可以截取字符串的一部分并与其他字段拼接
'''
var1 = 'Hello World!'
var2 = "Runoob"
print ("var1[0]: ", var1[0])                        # var1[0]:  H
print ("var2[1:5]: ", var2[1:5])                    # var2[1:5]:  unoo
print ("var2[-5:-1]: ", var2[-5:-1])                # var2[-5:-1]:  unoo
print ("已更新字符串 : ", var1[:6] + 'Runoob!')      # 已更新字符串 :  Hello Runoob!
# Out:
# var1[0]:  H
# var2[1:5]:  unoo
# var2[-5:-1]:  unoo
# 已更新字符串 :  Hello Runoob!

# %%
# 转义字符
# python 用反斜杠 \ 转义字符。如下表：
# 转义字符	     描述	                                实例
# \(在行尾时)	 续行符	                                >>> print("line1 \
#                                                     ... line2 \
#                                                     ... line3")
#                                                     line1 line2 line3
#                                                     >>> 
# \\	         反斜杠符号	                            >>> print("\\")
#                                                     \
# \'	         单引号		                            >>> print('\'')
#                                                     '
# \"	         双引号		                            >>> print("\"")
#                                                     "
# \a	         响铃	                                >>> print("\a")执行后电脑有响声。
# \b	         退格(Backspace)                        >>> print("Hello \b World!")
#                                                     Hello World!
# \000	     空	                                    >>> print("\000")
# 
#                                                     >>> 
# \n	         换行	                                >>> print("\n")
# 
#                                                     >>>
# \v	         纵向制表符	                          >>> print("Hello \v World!")
#                                                     Hello 
#                                                            World!
#                                                     >>>
# \t	         横向制表符	                            >>> print("Hello \t World!")
#                                                     Hello      World!
#                                                     >>>
# \r	         回车，将 \r 后面的内容移到字符串开头，    >>> print("Hello\rWorld!")
#              并逐一替换开头部分的字符，               World!
#              直至将 \r 后面的内容完全替换完成。	      >>> print('google runoob taobao\r123456')
#                                                     123456 runoob taobao
# \f	         换页	                                >>> print("Hello \f World!")
#                                                     Hello 
#                                                            World!
#                                                     >>> 
# \yyy	    八进制数，y 代表 0~7 的字符，               >>> print("\110\145\154\154\157\40\127\157\162\154\144\41")
#             例如：\012 代表换行。	                  Hello World!
#                                                     
# \xyy	    十六进制数，以 \x 开头，y 代表的字符，       >>> print("\x48\x65\x6c\x6c\x6f\x20\x57\x6f\x72\x6c\x64\x21")
#             例如：\x0a 代表换行	                  Hello World!    
#                                                     
# \other	    其它的字符以普通格式输出	 

# 使用 \r 实现百分比进度：
import time

for i in range(101): # 添加进度条图形和百分比
    bar = '[' + '=' * (i // 2) + ' ' * (50 - i // 2) + ']'
    print(f"\r{bar} {i:3}%", end='', flush=True)
    time.sleep(0.05)
print()
# Out:
# [==================================================] 100%

# %%
# 字符串运算符
'''
下表实例变量 a 值为字符串 "Hello"，b 变量值为 "Python"：
操作符	  描述	                                  实例
+	      字符串连接	                              a + b 输出结果： HelloPython
*	      重复输出字符串	                          a*2 输出结果：HelloHello
[]	      通过索引获取字符串中字符	              a[1] 输出结果 e
[ : ]	  截取字符串中的一部分，遵循左闭右开原则，    a[1:4] 输出结果 ell
          str[0:2] 是不包含第 3 个字符的。	
in	      成员运算符 - 如果字符串中包含给定          'H' in a 输出结果 True
          的字符返回 True	
not in	  成员运算符 - 如果字符串中不包含给定的      'M' not in a 输出结果 True
          字符返回 True	
r/R	      原始字符串 - 原始字符串：所有的字符串都是   print( r'\n' )
          直接按照字面的意思来使用，没有转义特殊或不  print( R'\n' )
          能打印的字符。 原始字符串除在字符串的第一
          个引号前加上字母 r（可以大小写）以外，与
          普通字符串有着几乎完全相同的语法。	
'''

a = "Hello"
b = "Python"
 
print("a + b 输出结果：", a + b)     # a + b 输出结果： HelloPython
print("a * 2 输出结果：", a * 2)     # a * 2 输出结果： HelloHello
print("a[1] 输出结果：", a[1])       # a[1] 输出结果： e
print("a[1:4] 输出结果：", a[1:4])   # a[1:4] 输出结果： ell
 
if( "H" in a) :                     # H 在变量 a 中
    print("H 在变量 a 中")
else :
    print("H 不在变量 a 中")
 
if( "M" not in a) :                 # M 不在变量 a 中
    print("M 不在变量 a 中")
else :
    print("M 在变量 a 中")
 
print (r'\n')                       # \n
print (R'\n')                       # \n
# Out:
# a + b 输出结果： HelloPython
# a * 2 输出结果： HelloHello
# a[1] 输出结果： e
# a[1:4] 输出结果： ell
# H 在变量 a 中
# M 不在变量 a 中
# \n
# \n

# %%
# 字符串格式化
'''
Python 支持格式化字符串的输出 。尽管这样可能会用到非常复杂的表达式，但最基本的用法是将一个值插入到一个有字符串格式符 %s 的字符串中。
符号	描述
# %c	    格式化字符及其ASCII码
# %s	    格式化字符串
# %d	    格式化整数
# %u	    格式化无符号整型
# %o	    格式化无符号八进制数
# %x	    格式化无符号十六进制数
# %X	    格式化无符号十六进制数（大写）
# %f	    格式化浮点数字，可指定小数点后的精度
# %e	    用科学计数法格式化浮点数
# %E	    作用同%e，用科学计数法格式化浮点数
# %g	    %f和%e的简写
# %G	    %f 和 %E 的简写
# %p	    用十六进制数格式化变量的地址
'''
print ("我叫 %s 今年 %d 岁!" % ('L8', 23))   # %s对应字符串，%d对应十进制数字
# Out:
# 我叫 L8 今年 23 岁!

# %%
# 三引号
# python三引号允许一个字符串跨多行，字符串中可以包含换行符、制表符以及其他特殊字符。
para_str = """这是一个多行字符串的实例   # 这是一个多行字符串的实例
多行字符串可以使用制表符                 # 多行字符串可以使用制表符
TAB ( \t )。                           # TAB ( 	 )。
也可以使用换行符 [ \n ]。                # 也可以使用换行符 [ 
也可以使用换行符 [ \n ]。                # ]。
"""
print (para_str)
# Out:
# 这是一个多行字符串的实例
# 多行字符串可以使用制表符
# TAB ( 	 )。
# 也可以使用换行符 [
#  ]。

# %%
# f-string
# 称之为字面量格式化字符串
# 格式化字符串以 f 开头，后面跟着字符串，字符串中的表达式用大括号 {} 包起来，它会将变量或表达式计算后的值替换进去，
name = 'Runoob'
f'Hello {name}'  # 替换变量，输出'Hello Runoob'

f'{1+2}'         # 使用表达式,输出'3'


w = {'name': 'Runoob', 'url': 'www.runoob.com'}
f'{w["name"]}: {w["url"]}'       # 'Runoob: www.runoob.com'

'''
# 1. 变量直接代入
name = 'Runoob'
res1 = f'Hello {name}'
print(res1)  # Hello Runoob

# 2. {} 内支持运算表达式
res2 = f'{1 + 2}'
print(res2)  # 3

# 3. 字典取值（注意引号区分：外层f用单引号，字典键用双引号）
w = {'name': 'Runoob', 'url': 'www.runoob.com'}
res3 = f'{w["name"]}: {w["url"]}'
print(res3)  # Runoob: www.runoob.com
'''
# Out:
# '\n# 1. 变量直接代入\nname = \'Runoob\'\nres1 = f\'Hello {name}\'\nprint(res1)  # Hello Runoob\n\n# 2. {} 内支持运算表达式\nres2 = f\'{1 + 2}\'\nprint(res2)  # 3\n\n# 3. 字典取值（注意引号区分：外层f用单引号，字典键用双引号）\nw = {\'name\': \'Runoob\', \'url\': \'www.runoob.com\'}\nres3 = f\'{w["name"]}: {w["url"]}\'\nprint(res3)  # Runoob: www.runoob.com\n'
